# %% [markdown]
# # Самостоятельная работа "Сравнение выборок"
#
# В этой работе Вы должны продемонстрировать умение сравнивать выборки, в которых распределение данных близко к нормальному.
#
#
# Образцы кода, который можно использовать для формирования отчета, основаны на данных из приложения "Баланс внимания". Желающие могут использовать свои данные или данные из проектов, в которых они участвовали.
#
# ### Требования к данным
# 1. Две подвыборки с количеством значений 15-30 в каждой.
# 2. Данные должны иметь четкую центральную тендецию (группироваться вокруг среднего).
#
#
# ### Требования к отчету
# В отчете должны быть:
# 1. Указание на источник данных с описанием условий получения.
# 2. Визуализация ранговых показателей двух выборок (ящики с усани или подобные иллюстрации)
# 3. Расчет достоверности различий (тест Стьюдента) вручную и с использованием библиотек.
#
# Все этапы расчетов должны сопровождаться наглядными иллюстрациями с подписями.
#
#
# При выполнении работы используйте образцы кода из блокнотов
#
# - [Работа с набором данных](Task_dataset_rt.ipynb)
#     - [Загрузка данных из текстового файла](Task_load_importtext.ipynb)
#     - [Загрузка данных с веб-страницы](Task_load_webpage.ipynb)
#     - [Загрузка данных в виде массива](Task_algo_vector.ipynb)
#
# - [Построение гистограммы распределения](Task_vis_hist.ipynb)
#
#
# - [Разведочный анализ набора данных с ВР](Task_eda_rt.ipynb) + rt9x2.tsv
#
# - [Групповой анализ данных](Task_balatte.ipynb)
# - [Групповой анализ данных с учетом условий](Task_balatte_condition.ipynb)
#
#
# ### Шаблон отчета
#
# В качестве шаблона для отчета рекомендуется использовать блокнот, в котором уже задана структура из заголовков.
# Перед сдачей удалите всё лишнее.

# %%
# import ...

# %% [markdown]
# ##   Источник данных

# %% [markdown]
# Я использую данные, полученные ...

# %% [markdown]
# ##   Визуализация данных

# %%
# рисунок

# %% [markdown]
# На рисунке видно...

# %% [markdown]
# ##  Сравнение двух выборок
#
# Тест Стьюдента проводится по формуле...

# %% [markdown]
# Сравнение выборок показало...
