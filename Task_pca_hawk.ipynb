# %% [markdown]
# # PCA IRL

# %% [markdown]
# Просмотрите статью [Contrasting molecular and morphological evidence for the identification of an anomalous Buteo: a cautionary tale for hybrid diagnosis](https://peerj.com/articles/2850/)
#
# Данные в [DOC-файле](C:\DOC\JAVA\MAME\hawk_morphometric.docx)
#
# Сочетание морфометрических и генетических методов является нормой для современных популяционных исследований.

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd

# %% [markdown]
# На первой картинке представлены образцы объектов исследования...
# > птичку жалко!
# *&copy; Гайдай Л. "Кавказская пленница" (1966)*
#
# ![](hawk_fig-1-1x.jpg)
#
#  Figure 1: Comparison of adult Eastern Red-shouldered Hawk (r) with WFB 4816 (l).
# (A) Undersides. Note dark throat and dark belly markings of WFB 4816. (B) Upper tails. Note six tail bands of WFB 4816. (C) Upper wings. Note lack of white spotting on upper wings of WFB 4816.

# %% [markdown]
# Данные
#
# Авторы редуцировали к 2-м компонентам

# %% [markdown]
# ![](hawk_fig-2-1x.jpg)
#
# Figure 2: Plot of the first two principle components based on the PCA of five measurements from 103 adult eastern Red-shouldered Hawks (B. lineatus subspp.), California Red-shouldered Hawks (B. l. elegans), and western Red-tailed Hawks (B. j. calurus) representing both sexes showing that the putative hybrid is intermediate in its morphometric measurements between Red-shouldered Hawk and Red-tailed Hawk.

# %% [markdown]
# Давайте воспроизведем...

# %%
G=pd.read_csv('hawk_microsatellite.csv', skiprows=6)
G
# Out:
#           population   sample_ID  A110-allele1  A110-allele2  A303-allele1  \
# 0    possible hybrid  WFCBsample           215           215           240
# 1            elegans     CA10886           215           217           240
# 2            elegans     CA10977           215           217           240
# 3            elegans     CA11055           217           217           240
# 4            elegans     CA11057           215           215           240
# 5            elegans     CA11061           215           217           240
# 6            elegans     CA11077           217           217           240
# 7            elegans     CA13510           215           217           240
# 8            elegans     CA13609           215           217           240
# 9            elegans     CA13610           217           217           242
# 10           elegans     CA13618           217           221           240
# ...

# %%
pcolor(G.iloc[:,2:], cmap='PuRd');colorbar();
