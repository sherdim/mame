# %% [markdown]
# ## Управление с клавиатуры

# %% [markdown]
# Jupyter Notebook имеет два различных режима ввода клавиатуры.
#
# *Режим редактирования* позволяет вводить код / текст в ячейку и обозначается зеленой рамкой ячейки.
#
# *Командный режим* позволяет вызывать с клавиатуры действия на уровне блокнота, при этом активная ячейка обозначается серой рамкой с синим левым краем.

# %% [markdown]
# ## Упражнение
#
# Например, вы изучаете блокнот с кодом, и хотите разобраться в сложных расчетах, выполненных в одной из ячейеек. Один из способов - посмотреть, чему равны промежуточные переменные.
#
# 1. Сделайте активной следующую ячейку
# 1. Нажмите `Ctrl-Enter` - посмотрите ответ
# 1. Нажмите клавишу `A` (русская `Ф`)
# 1. В созданной ячейке нажмите `Enter` для перехода в *режим редактирования* и введите `a` (латинскими буквами) , т.е. команду, чтобы посмотреть значение переменной
# 1. Нажмите `Ctrl-Enter` - посмотрите ответ
# 1. Нажмите клавишу `D` (русская `В`) два раза, чтобы удалить ячейку
#
# Повторите для переменной `b`.

# %%
a= 3**2 + 13.5 - 6/1.5
b= 234/198.0
(a**b)

# %% [markdown]
# В виде кнопок на панели выведены команды Вырезать, Копировать и Вставить ячейку. Вырезать - это значит удалить и поместить в буфер обмена. Таким образом, вместо двойного нажатия клавиши `D` можно один раз нажать клавишу `X` - ненужная ячейка будет удалена. Ее содержимое будет находиться в буфере обмена, пока вы не вырежете или скопируете что-нибудь еще.

# %% [markdown]
# ## Упражнение
#
# Другой из способов разобраться в сложных расчетах, выполненных в одной из ячейеек, - посмотреть, чему равны переменные на каждом этапе.
#
# 1. Сделайте активной следующую ячейку и нажмите `Enter` для перехода в *режим редактирования*
# 1. Передвиньте курсор клавишами со стрелочками на вторую позицию в начале 3-й строки, сразу за `x`
# 1. Нажмите `Shift-Ctrl-Minus` (минус между клавишами `0` и `+`) для разбиения ячейки на две в текущей позиции курсора
# 1. Нажмите клавишу со стрелочкой вверх, чтобы перейти в первую из пары полученных ячеек
# 1. Нажмите `Ctrl-Enter` - посмотрите ответ
# 1. Нажмите `Shift-M` для слияния ячеек обратно.
# 1. Нажмите `Enter` для перехода в *режим редактирования*, передвиньте курсор клавишами со стрелочками на вторую позицию в начале 3-й строки, сразу за `x`, и с помощью клавиши `Del` уберите лишние переносы строк, чтобы вернуть код в исходное состояние
#
# Повторите для 4-й строки.

# %%
x= 1.0
x+= (8.3)/2
x/= 3**-0.4
x*= 2.5
x

# %% [markdown]
# Операции разделения, слияния и перемещения ячеек доступны из меню с использованием мыши.
#
# Список всех возможных команд доступен из меню `Help - Keyboard Shrtcuts`
