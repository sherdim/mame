# %% [markdown]
# # 🗎 Сравнение выборок

# %%
from IPython.display import display, Markdown
display(Markdown(open('_prew.md', 'r', encoding='utf-8').read()))
# Out:
# <div class="admonition note">
# <p class="admonition-title">О среде выполнения </p>
# <p>
#     Данная расчётно-графическая работа выполняется в <a href=i_sreda.html>программной среде Jupyter Notebook</a>.
# Если у Вас на компьютере нет установленной вычислительной среды, см.
#   <a href=i_sredaonline.html>Выполнение расчетно-графических работ онлайн</a>.
# </p>
# </div>

# %% [markdown]
# В этой работе Вы должны продемонстрировать умение сравнивать выборки, в которых распределение данных близко к нормальному.

# %% [markdown]
# **Задание**: представить отчет о сравнении нескольких выборок, различающихся по 1-2 условиям.

# %% [markdown]
# В качестве уникального для каждого студента источника данных предлагается использовать результаты самотестирования с помощью теста "[Баланс внимания](w_data1)".
#
# На основании навыков, полученных в ходе практических занятий, необходимо:
#
# 1. Обработать данные с помощью освоенных методик.
# 2. Сформировать отчет с иллюстрациями.

# %% [markdown]
# Поощряется использование данных из собственного научного проекта.
# При использовании собственных данных необходимо проконсультироваться с преподавателем по поводу соответствия требованиям к работе.

# %% [markdown]
# ## Требования к данным
#
# 1. Две подвыборки с количеством значений 15-30 в каждой.
# 2. Данные должны иметь четкую центральную тенденцию (группироваться вокруг среднего).

# %% [markdown]
# ## Требования к отчету
# В отчете должны быть:
# 1. Указание на источник данных с описанием условий получения.
# 2. Визуализация ранговых показателей двух выборок (ящики с усами или подобные иллюстрации)
# 3. Расчет достоверности различий (тест Стьюдента) вручную и с использованием библиотек.
#
# Все этапы расчетов должны сопровождаться наглядными иллюстрациями с подписями.
#
# Описывайте все полученные значения и рисунки с той степенью подробности, чтобы  читателю отчета было понятно, как и почему проводится анализ. Если какие-то сведения кажутся Вам само собой разумеющимися, то такую информацию можно опустить.
#
# При выполнении работы используйте образцы кода из блокнотов. Откройте все блокноты-доноры, сориентируйтесь какие задачи решаются в них и выберите только те фрагменты кода, которые нужны Вам для Вашей задачи.

# %% [markdown]
# ### Шаблон отчета
#
# В качестве шаблона для отчета рекомендуется использовать блокнот, в котором уже задана структура из заголовков. Сохраните блокнот под именем `granada_Familia.ipynb`.
# Перед сдачей удалите всё лишнее.

# %% [markdown]
# #### Источник данных

# %% [markdown]
# Я использовал данные, полученные ...

# %% [markdown]
# #### Визуализация данных

# %%
# рисунок

# %% [markdown]
# На рисунке видно...

# %% [markdown]
# #### Сравнение двух выборок
#
# Для сравнения выборок использовал тест Стьюдента ...

# %%
# import ...

# %% [markdown]
# Сравнение выборок показало...

# %%
from IPython.display import display, Markdown
display(Markdown(open('_postw.md', 'r', encoding='utf-8').read()))
# Out:
# В конце отчета по расчётно-графической работе обязательно сделайте вывод.
#
# 1. Основной результат. Прежде всего в выводе должен прозвучать ответ на поставленный вопрос.
# Что было целью работы, то и должно быть указано в выводе с конкретным числовым результатом.
#
# 2. Ограничения данной работы. Если в ходе работе были выявлены новые обстоятельства, которые привели к изменению хода работы, к ошибкам, к необходимости переосмысления возможности ее выполнения, то эти соображения надо изложить во вторую очередь.
#
# 3. Педагогические и эмоциональные замечания. Поскольку эта работа учебная, то можно поделиться впечатлениями от самого процесса решения задачи. Что было сложным, что особенно понравилось, что оказалось удивительным и неожиданным.
