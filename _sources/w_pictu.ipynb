# %% [markdown]
# # 🗎 Анализ изображения

# %%
from IPython.display import display, Markdown
display(Markdown(open('_prew.md', 'r', encoding='utf-8').read()))
# Out:
# <div class="admonition note">
# <p class="admonition-title">О среде выполнения </p>
# <p>
#     Данная расчётно-графическая работа выполняется в <a href=i_sreda.ipynb>программной среде Jupyter Notebook</a>.
# Если у Вас на компьютере нет установленной вычислительной среды, см.
#   <a href=i_sredaonline.ipynb>Выполнение расчетно-графических работ онлайн</a>.
# </p>
# </div>

# %% [markdown]
# Проверьте работу приведенного алгоритма подсчета колоний на других фрагментах этого или других изображениях.
#
# Сделайте вывод о возможных путях усовершенствования алгоритма при работе с выбранными вами образцами.

# %% [markdown]
# ## Требования к отчету
# В отчете должны быть:
# 1. Указание на источник данных.
# 2. Обоснование выделения фрагмента с заданным положением и размером.
# 3. Комментарий по поводу каждого выводимого значения, рисунока или операции по подбору параметров.
#
# Если какие-то операции кажутся вам понятными и не требующими комментариев - объединяйте их код со следующими ячейками с кодом, укрупняя блоки кода.
# Если подходящий блок кода содержит необходимую вычислительную операцию и дополнительный код для построения рисунка, который Вы не хотите комментировать, то оставьте только необходимую Вам часть кода, а остальное удалите.
#
# Рекомендуемый порядок включает проверку алгоритма на каком-нибудь фрагменте изображения, похожего на исходный фрагмент, то есть с четко различимыми колониями стафилококка на светлом агаре.
# Когда Вы подтвердите, что алгоритм работает, попробуйте взять другой более сложный фрагмент - или с худшим разрешением, или колониями разной формы и четкости, с другой цветовой гаммой.
# Приветствуется использование собственных изображений с большим количеством контрастных объектов (не обязательно круглых). Это могут быть пятна на поверхностях, узоры на одежде, любые природные паттерны с нерегулярным расположением отдельных частей.
# Возможно, придется подстраивать некоторые параметры выделения контуров или проводить предварительное сглаживание для удаления шума.
# Сравните успешность алгоритма для четких и проблемных изображений.

# %%
from IPython.display import display, Markdown
display(Markdown(open('_postw.md', 'r', encoding='utf-8').read()))
# Out:
# В конце отчета по расчётно-графической работе обязательно сделайте вывод.
#
# 1. Основной результат. Прежде всего в выводе должен прозвучать ответ на поставленный вопрос.
# Что было целью работы, то и должно быть указано в выводе с конкретным числовым результатом.
#
# 2. Ограничения данной работы. Если в ходе работе были выявлены новые обстоятельства, которые привели к изменению хода работы, к ошибкам, к необходимости переосмысления возможности ее выполнения, то эти соображения надо изложить во вторую очередь.
#
# 3. Педагогические и эмоциональные замечания. Поскольку эта работа учебная, то можно поделиться впечатлениями от самого процесса решения задачи. Что было сложным, что особенно понравилось, что оказалось удивительным и неожиданным.
