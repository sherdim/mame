# %% [markdown]
# Provided by  Welter Schultes, Francisco
#
# Locality: N Italy: Baveno, near Lago Maggiore
#
# http://www.animalbase.uni-goettingen.de/zooweb/servlet/AnimalBase/list/thumbnails?taxon_id=14088&include_synonyms=false

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
u='Argna-ferrari_02.jpg'
I=imread(u)

# %%
X=I[350:820,0:470, 0]
imshow(X, 'gray')

# %% [markdown]
# Попробуйте алгоритм на изображениях других видов
# http://flickrhivemind.net/Tags/cerionidae/Interesting
