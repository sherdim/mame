# %% [markdown]
# Предположим, что группа потенциальных покупателей кормов для домашних животных была опрошена по типу домашнего животного, которым они владели (фактор А). У отдельных людей были либо кошки, либо собаки. Затем людей спросили об их предпочтениях в покупке корма для домашних животных (фактор В). В частности, владельцев кошек спрашивали только о кормах для кошек, производимых брендами X, Y и Z. Владельцев собак спрашивали только о кормах для собак, производимых брендами X, Y и Z.
#
# - Вложенный
# - Скрещенный

# %% [markdown]
# Предположим, что группа потенциальных покупателей кормов для домашних животных была опрошена по типу домашнего животного, которым они владели (фактор А). У отдельных людей были либо кошки, либо собаки. Затем людей спросили об их предпочтениях в покупке корма для домашних животных (фактор В). В частности, владельцев кошек спрашивали только о кормах для кошек, производимых брендами X, Y и Z. Владельцев собак спрашивали только о кормах для собак, произведенных теми же брендами.
#
# Это исследование может быть проанализировано с использованием двухуровневой модели ANOVA, потому что...
#
# - В исследовании было два участника.
# - Фактор А имеет два уровня.
# - Фактор В имеет два уровня.
# - Есть два фактора.
